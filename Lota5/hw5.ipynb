# %% [markdown]
# # **Stundatöfluröðun á VON**

# %% [markdown]
# ## **Inngangur**
#
# Nú þegar kennslustofur og tímar dagsins eru af takmörkuðu magni reynist það verkefni erfitt að smíða stundtöflu fyrir kennslustundir Háskóla Íslands. Það þarf að taka gríðarlega margt til skoðunnar, námskeið geta ekki verið kennd á sama tíma vegna áresktra nemenda eða kennara og það þarf að finna stofur sem rýma námskeiðið svo fátt sé nefnt. Markmið okkar með þessu verkefni er þar með að raða niður námskeiðum háskólans þannig að stundataflan virki sem best fyrir sem flesta.
#
# Annað markmið verkefnisins er að staðla og einfalda stundatöflugerðina til þess að tryggja samhengi milli ára sem og auðvelda gerð hennar. Þetta verður meðal annars útfært með því að taka upp svokallaða stokkakerfið sem var notað árum áður á VON og lýst er í verkefnalýsingunni <a href="https://haskoliislands.instructure.com/courses/33829/assignments/154425">hér</a>.
#
# Þetta verkefni verður leyst með því að setja upp heiltölubestunarverkefni til þess að raða námskeiðum í stokanna sem og að hámarka fyrrnefndu gæði stundatöflurnar en þessi gæði verða betur rædd í framsetningu líkansins í næsta hluta.

# %% [markdown]
# ## **Líkan**
# Við skilgreinum heiltölubestunarverkfni. Í verkefninu verður aðeins útfærð röðun fyrir námskeið á Verkfræði- og náttúruvísindasviðs (VON) en yfirfæra má lausnina á sérhvert svið háskólans.
#
# #### **Mengi:**
#
# - **$N_\text{VON}$** er mengi sérhvers námskeiðs á VON
# - **$S=\{0,\dots, 7\}$** er mengi stokka í stundatöflunni þannig að 0 táknar utan stundatöflu og $i, i>0$ táknar stokk $i$.
# - **$R$** er mengi sérhverrar kennslustofu.
# - **$\mathcal M$** er mengi allra námsbrauta þannig að um námsbraut $m\in  \mathcal M$ gildir $m\subseteq N_\text{VON}$.
# - **$NN$** er mengi allra tvennda $(n_1,n_2)\in N_\text{VON} \times N_\text{VON}$ þannig að það sé nemandi skráður í bæði námskeið og fjöldi vikulegra kennslustunda í báðum námskeiðum er meiri en 5. (ef minni eða jafn og 5 þá má kenna bæði á sama tíma og þarf því ekki að flokka sem árekstur).
# - **$\overline S_n$** er mengi þeirra slotta sem námskeið $n$ var í á síðasta kennsluári.
# - **$\overline R_n$** er mengi þeirra kennslustofa sem námskeið $n$ var í á síðasta kennsluári.
#
#
# #### **Fastar**
# - $T_n$ táknar fjölda vikulegra kennslustunda í námskeiði $n\in N_\text{VON}$.
# - $A_n$ táknar fjölda nemenda skráða í námskeið $n\in N_\text{VON}$.
# - $C_r$ táknar fjölda sæta í kennslustofu $r\in R$
# - $D_{n_1,n_2}$ táknar fjöld nemenda í árekstri í námskeiði $n_1$ og $n_2$
#
# #### **Ákvörðunarbreytur**
# Við byrjum á því að skilgreina megin ákvörðunarbreytuna okkar
# $$
# x_{n,s,r}\in \{0,1\},\quad n\in N_\text{VON}, \quad s\in S,\quad r\in R
# $$
# sem er 1 ef námskeið $n$ er kennt í stokki $s$ í kennslustofu $R$.
#
# Við skilgreinum svo einnig gerviákvörðunarbreytu
# $$
# z_{n_1,n_2,s}\in \{0,1\},\quad (n_1,n_2)\in NN \land s\in S
# $$
# sem er 1 ef árekstur er milli námskeiða $n_1$ og $n_2$ Í slotti s og 0 annars.
#
# #### **Skorður**
#
# Skorðurnar sem að við setjum á verkefnið eru tvískiptar. Annars vegar til þess að tryggja að verkefnið sé möguleg og hinsvegar skorður settar til þess að lágmarka árekstra.
#
# Við byrjum á fyrri gerðinni:
# - Sérhvert námskeið er kennt nákvæmlega einu sinni þ.e.a.s. er í nákvæmlega einu slotti og einni kennslustofu. Þessa skorðu má tákna:
# $$
# \sum_{s\in S}\sum_{r\in R}x_{n,s,r} = 1, \quad \forall n\in N_\text{VON}
# $$
# - Námskeið í sama slotti geta ekki verið í sömu stofu nema þau séu með færri en 5 vikulegar kennslustundir. Hver stokkur inniheldur einungis 5 vikulegar kennslustundir svo tímar í ákveðinni kennslustofu í ákveðnu slotti verða að vera minni en 5. Við táknum þetta:
# $$
# \sum_{n\in N_\text{VON}}T_n x_{n,s,r} \leq 5, \quad \forall (s,r)\in S\times R
# $$
# - Námskeið getur einungis verið kennt í kennslustofu sem það passar í. Það má tákna
# $$
# A_nx_{n,x,r} \leq C_r, \quad \forall (n,s,r)\in N_\text{VON} \times S \times R
# $$
# Við höfum svo skorður til þess að bæta líkanið.
# - Engir árekstrar fyrir skylduáfanga á sömu námsbraut eru leyfilegir þ.e.a.s. hver stokkur getur mest innihaldið 5 kennslustundir af skyldunámskeiðum á sömu námsbraut. Þetta má tákna:
# $$
# \sum_{\substack{n\in m \\ r\in R}} T_n x_{n,s,r} \leq 5, \quad \forall (m,s)\in \mathcal M\times S
# $$
# Við setjum svo skorður á $z$ þannig að hún uppfylli árekstrarskilyrðin þ.e.a.s. setjum skorður þannig að ef námskeið $n_1$ og $n_2$ eru kennd í sama slotti s óháð kennslustofu þá er $z_{n_1,n_2,s}=1$ en annars 0. Við höfum þrjár skorður:
# - Ef námskeið $n_1$ ekki kennt í slotti $s$ þá verður $z$ að vera 0, þ.e.a.s.
# $$
# z_{n_1,n_2,s} \leq \sum_{r\in R} x_{n_1,s,r},\quad \forall (n_1,n_2)\in NN \land s\in S
# $$
# - Ef námskeið $n_2$ ekki kennt í slotti $s$ þá verður $z$ að vera 0, þ.e.a.s.
# $$
# z_{n_1,n_2,s} \leq \sum_{r\in R} x_{n_2,s,r},\quad \forall (n_1,n_2)\in NN \land s\in S
# $$
# - Ef báðar summur 1 þ.e.a.s. bæði kennd í slotti $s$ þarf $z$ að vera 1.
# $$
# z_{n_1,n_2,s} \geq -1 + \sum_{r\in R} x_{n_1,s,r} + \sum_{r\in R} x_{n_2,s,r},\quad \forall (n_1,n_2)\in NN \land s\in S
# $$
#
# #### **Markföll**
#
# Við skilgreinum mörg markföll þannig að það bestar fyrst eftir fyrsta markfallinu, og svo eftir öðru svo fremi sem það gerir ekki lausnin verri m.t.t. fyrsta markfallsisn o.s.frv. Við setjum því markföllin fram í þeirri röð sem þau er bestuð eftir.
# - Fyrst viljum við lágmarka lágmarka fjölda námskeiða í slotti 0 þ.e.a.s. sem enda fyrir utan stundatöflu. Það má tákna
# $$
# \min \zeta_1 = \sum_{\substack{r\in R\\ n\in N_\text{VON}}}T_n x_{n,0,r}
# $$
# - Við viljum að stundataflan sé eins lík þeirri og í fyrra. það má tákna:
# $$
# \max \zeta_2 = 2\cdot\sum_{\substack{n\in N_{\text{VON}}}}\sum_{s\in \overline S_n} \sum_{r\in \overline R_n}x_{n,s,r} + \sum_{\substack{n\in N_{\text{VON}}}}\sum_{s\in \overline S_n} \sum_{r\in R}x_{n,s,r} + \sum_{\substack{n\in N_{\text{VON}}}}\sum_{s\in S} \sum_{r\in \overline R_n}x_{n,s,r}
# $$
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; Þar sem það hefur mest vægi ef bæði í sömu stofu og sama slotti en minna ef aðeins annað gildir.
# - Við viljum lágmarka árekstra,
# $$
# \min \zeta_3 = \sum_{\substack{s\in S \\ (n_1,n_2)\in NN}} D_{n_1,n_2}\cdot z_{n_1,n_2,s}
# $$

# %% [markdown]
# **Hlutir sem þarf að skoða í flóknari líkani**
#
# - Ef bara tveir tímar (3) í hvort slottið á að fara
#
#
# - þarf ekki að hafa kennara árekstra
#
# - takmarka fjarlægð milli kennslustunda
# - takmarka tíma milli kennslustunda
# - lágmarka árekstri
# - fyrir áresktra $\min \sum_{n_1< n_2} C_{n_1,n_2}*z_{n_1m,n_2}$ þar sem $z$ segir til um hvort námskeið séu kennd á sama tíma
# - Hafa núverandi töflu, töflu efir bestun, töflu eftir bestun sem lágmarkar árekstra með timeout 5 mín.
# - Reyna sem mest að hafa stundatöflu sem svipaðasta
# - setObjectiveN
# - priority fyrst árekstrar, svo eins og í fyrra... í staðinn fyrir að setja vigtir.
# - til þess að það sé eins hámarka summu yfir x_n,s,r yfir S og R frá því í fyrra

# %% [markdown]
# ## **Niðurstöður**
#
# Verkefni að ofan var sett upp og leyst með Gurobipy en alla útfærslu má sjá í viðauka að neðan. Niðurstöður voru svo skoðaðar fyrir eftirfarandi námsbraut:
#
# ```{bash}
# [
#       "5054RAF401G20250",
#       "5054RAF402G20250",
#       "5054RAF403G20250",
#       "5054RAF404G20250",
#       "5054RAF405G20250",
#       "5054RAF406G20250",
#       "5054RAF407G20250"
# ]
# ```
#
# #### **Stundataflan í dag**
# En áður hafist er handa við lausn verkefnisins skulum við skoða hvernig núverandi stundatafla lítur út fyrir námsbrautina valda að ofan.
#
# | Time       | Mon | Tue | Wed | Thu | Fri |
# |------------|------------|------------|------------|------------|------------|
# | 08:20-09:50 |  | Líkindaaðferðir (V02-138) | Greining og uppbygging rása (V02-155) |  | Rafeindatækni 1 (V02-258) |
# | 10:00-11:30 | Rafeindatækni 1 (V02-148, sérstofa VR-2) |  | Rafeindatækni 1 - verklegt (V03-113) | Líkindaaðferðir (V02-156 Sérstofa VR-2) | Greining og uppbygging rása (V02-261) |
# | 11:40-13:10 |  |  |  |  |  |
# | 13:20-14:50 | Rafsegulfræði (V02-156 Sérstofa VR-2) | Greining og uppbygging rása - verklegt (V03-113) | Rafsegulfræði (V02-258) | Greining og uppbygging rása - verklegt (V03-113) | Líkindaaðferðir - verklegt (V03-113) |
# | 15:00-16:30 |  |  |  |  |  |
#
# Auk þess sem að við höfum
#
# - Fjöldi námskeiða í slotti 0: **0**
# - Fjöldi árekstra: **330**
#
# #### **Fyrsta keyrsla**
#
# Byrjað var á því að keyra grunnverkefnið þ.e.a.s. ákvarða hvort það sé til möguleg lausn á verkefninu. Það er gert með því að keyra verkefnið fyrir ákvörðunarbreytuna $x$ og einungis markfallið til þess að lágmarka fjölda kennslustunda í slotti 0.
#
# - Fjöldi námskeiða í slotti 0: **0**
# - Fjöldi árekstra: ****
#
# Við skoðum svo stundatöfluna fyrir ofangreinda námsbraut.
#
# | Time       | Mon | Tue | Wed | Thu | Fri |
# |------------|------------|------------|------------|------------|------------|
# | 08:20-09:50 | Líkindaaðferðir (G-139) |  | Greining og uppbygging rása - verklegt (Ág-201) | Rafeindatækni 1 (N-131) | Líkindaaðferðir - verklegt (Ág-304) |
# | 10:00-12:20 | Rafeindatækni 1 (N-131) |  | Líkindaaðferðir (G-139) |  | Greining og uppbygging rása - verklegt (Ág-201) |
# | 13:20-14:50 |  |  | Rafeindatækni 1 - verklegt (HB-5) | Greining og uppbygging rása (VHV-023 Auðarsalur)<br>Rafsegulfræði (Ág-309) |  |
# | 13:20-15:40 | Rafeindatækni 1 - verklegt (HB-5) | Greining og uppbygging rása (VHV-023 Auðarsalur)<br>Rafsegulfræði (Ág-309) |  |  |  |

# %% [markdown]
# ## **Niðurlag**
#
# Setja upp vef þar sem stundatafla getur verið kynnt, kennarar gera athugasemdir, uppfærð

# %% [markdown]
# ## **Viðauki**

# %% [markdown]
# ### **Innlestur og vinnsla gagna**

# %%
import json
import requests
import pandas as pd
from io import StringIO
from collections import defaultdict

# Raw GitHub URL
clash_url = "https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/course_clashes.json"
student_numbers_url = "https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/student_numbers.json"
top_groups_url = "https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/top_course_groups.json"
course_schedule_url = "https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/course_schedule.json"
room_csv_url = "https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/rooms.csv"

# Download and read CSV into DataFrame
response = requests.get(room_csv_url)
df_rooms = pd.read_csv(StringIO(response.text))

# Load student numbers (fjöldi nemenda í hverju námskeiði)
Students = json.loads(requests.get(student_numbers_url).text)

# Load top course groups (námsbrautir)
top_course_groups = json.loads(requests.get(top_groups_url).text)

response = requests.get(clash_url)
clash_data = json.loads(response.text)
# (Optional) Convert back to tuple keys
Clash = {
    tuple(k.split("__")): v for k, v in clash_data.items()
}

# Fetch and read into DataFrame
response = requests.get(course_schedule_url)
df_schedule = pd.read_json(response.text)

buildings = ['Askja', 'Árnagarður',  'gimli', 'Gimli', 'Gróska', 'Háskólabíó', 'Háskólatorg', 'Veröld - Hús Vigdísar', 'VR-2']

filtered_room_df = df_rooms[
    (df_rooms["building_name"].isin(buildings)) &
    (df_rooms["type"] == 3)
]

Rooms = (
    filtered_room_df.dropna(subset=["capacity"])
               .set_index("room_name")["capacity"]
               .to_dict()
)


# Ensure timestamps are parsed as datetime (if not already)
df_schedule['start_time'] = pd.to_datetime(df_schedule['start_time'])
df_schedule['end_time'] = pd.to_datetime(df_schedule['end_time'])

# Calculate duration in minutes
df_schedule['duration_minutes'] = (df_schedule['end_time'] - df_schedule['start_time']).dt.total_seconds() / 60

# Filter to only include courses scheduled for at least 6 weeks
df_schedule = df_schedule[df_schedule['end_week'] - df_schedule['start_week'] + 1 >= 6]

# Group by course_key and sum the duration
duration_by_course = (
    df_schedule.groupby('course_key')['duration_minutes']
    .sum()
    .reset_index(name='duration_minutes')
)

# Convert to number of 46-minute periods, round, clip max to 5
duration_by_course['periods'] = (
    (duration_by_course['duration_minutes'] / 46)
    .round()
    .clip(upper=5)
    .astype(int)
)

# Final output: dictionary of course_key to number of periods
T = dict(zip(duration_by_course['course_key'], duration_by_course['periods']))
T = {k: v for k, v in T.items() if k in Students}


# Initialize dictionaries
course_slots = defaultdict(set)
course_rooms = defaultdict(set)

# Iterate through the schedule
for _, row in df_schedule.iterrows():
    course = row['course_key']
    if course not in Students:
        continue

    # Extract all overlapping slots (should be a list)
    slots = row['overlapping_slots']
    if isinstance(slots, list):
        course_slots[course].update(slots)

    # Extract room(s) — can be multiple, e.g. 'Gr-321, Ada sérstofa'
    room_field = row['room']
    if isinstance(room_field, str):
        # Split on commas if multiple rooms listed in one row
        rooms = [r.strip() for r in room_field.split(',')]
        course_rooms[course].update(rooms)
# Out:
# /Users/johannesreykdal/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /var/folders/f4/696wvzy10_x0nx1mhv2tsws80000gn/T/ipykernel_30571/2951138270.py:33: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_schedule = pd.read_json(response.text)

# %%
# filterum námsbrautir til þess að skoða einungis námskeið sem að við erum að skoða

filtered_top_course_groups = []

for group in top_course_groups:
    filtered_courses = [c for c in group['courses'] if c in T]
    
    if filtered_courses:  # only keep if there are valid courses left
        filtered_top_course_groups.append({
            'courses': filtered_courses,
            'count': group['count']  # keep the count as-is
        })
        
# filterum eins course_rooms
filtered_course_rooms = {
    course: {room for room in rooms if room in Rooms}
    for course, rooms in course_rooms.items()
}

# %%
import requests
import json
response = requests.get("https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/course_clashes.json")
course_clashes = json.loads(response.text)
response = requests.get("https://raw.githubusercontent.com/tprunarsson/student_hitt/main/data/schedule_clashes.json")
schedule_clashes = json.loads(response.text)

# Count matches and mismatches
match_count = 0

total_clashes = 0
for key, student_count in course_clashes.items():
    if key in schedule_clashes:
        match_count += 1
        print(f"  {key.replace('__', ' vs ')} → {student_count} students")
        total_clashes += student_count

print(f"\nClashes that are both in student registrations *and* schedules: {match_count}")
print(f"Total students in matching clashes: {total_clashes}")
# Out:
#   1011ÞJÓ437G20250 vs 5053FER208G20250 → 1 students
#   1011ÞJÓ437G20250 vs 5053LÍF201M20250 → 1 students
#   1011ÞJÓ437G20250 vs 5053UAU213M20250 → 1 students
#   1011ÞJÓ437G20250 vs 5053UAU214M20250 → 1 students
#   1013HAG201G20250 vs 5055STÆ202G20250 → 1 students
#   1016VIÐ204G20250 vs 5051HBV601G20250 → 1 students
#   1016VIÐ204G20250 vs 5055STÆ203G20250 → 1 students
#   1016VIÐ402G20250 vs 5051HBV401G20250 → 2 students
#   1016VIÐ402G20250 vs 5051HBV601G20250 → 3 students
#   1016VIÐ402G20250 vs 5051IÐN612M20250 → 11 students
#   1016VIÐ402G20250 vs 5051TÖL212M20250 → 2 students
#   1016VIÐ402G20250 vs 5051VÉL406G20250 → 2 students
#   1016VIÐ402G20250 vs 5051VÉL608G20250 → 3 students
#   1016VIÐ402G20250 vs 5051VÉL609G20250 → 3 students
#   1016VIÐ402G20250 vs 5055EVF602M20250 → 1 students
#   1016VIÐ402G20250 vs 5055STÆ202G20250 → 1 students
#   1016VIÐ415G20250 vs 5055EVF401G20250 → 2 students
#   1016VIÐ604G20250 vs 5051IÐN401G20250 → 2 students
# ...

# %%
import gurobipy as gp
from gurobipy import GRB
from collections import defaultdict
from itertools import combinations

# %%
# Mengi
S = set(range(8)) # stokkur 0 er utan stokkar
N = set(T.keys())
R = set(Rooms.keys()) # kennslustofur
# Fækka breytum eins og við getum
NSR = set([(n,s,r) for s in S for n in N for r in R if Students[n] <= Rooms[r] * 1.2])
# Filtered NN: only course pairs with more than 4 shared students
NN = {
    (n1, n2)
    for (n1, n2) in Clash.keys()
    if Clash[(n1, n2)] > 4
}
NN_f = {t for t in NN if all(x in N for x in t)}
filtered_NN = [(n1,n2) for (n1,n2) in NN_f if T[n1] + T[n2] > 5 ]
S0 = list(range(1,8))

# %% [markdown]
# ### **Líkan**

# %%
def ordering(arekstrar = False, nytni = False, eins = False):
    model = gp.Model()
    x = model.addVars(N,S,R,vtype=GRB.BINARY)

    # sérhvert námskeið aðeins kennt í einni stofu og í einu slotti
    model.addConstrs(
        (gp.quicksum(x[n, s, r] for s in S for r in R) == 1 for n in N),
        name="course_assignment"
    )
    
    # námskeið í sama slotti geta ekki verið í sömu stofu. nema þau séu með færri en 5 námskeið
    for s in S0:
        for r in R:
            model.addConstr(
                gp.quicksum(x[n, s, r]*T[n] for n in N) <= 5,
                name=f"one_course_per_room_slot_{s}_{r}"
            )

    # námskeið þarf að vera kennt í stofu sem það passar í
    model.addConstrs(
        (x[n, s, r] * Students[n] <= Rooms[r] for n in N for s in S0 for r in R),
        name="room_capacity"
    )
    
    
    if arekstrar:
        # engin skyldunámskeið kennd á sama tíma
        for namsbraut_index in range(len(filtered_top_course_groups)):
            for s in S0:
                model.addConstr(
                    gp.quicksum(x[n, s, r] * T[n] for n in filtered_top_course_groups[namsbraut_index]['courses'] for r in R) <= 5,
                    name=f"max_classes_{namsbraut_index}_slot{s}"
                )

    

    # Lágmarka áresktra, bætum við gervi breytu z
    z = model.addVars(
        ((n1,n2,s) for (n1,n2) in filtered_NN for s in S),
        vtype=GRB.BINARY,
        name="clash"
    )
    
    # Add linearization constraints
    for (c1, c2, s) in z.keys():
        model.addConstr(z[c1, c2, s] <= gp.quicksum(x[c1, s, r] for r in R))
        model.addConstr(z[c1, c2, s] <= gp.quicksum(x[c2, s, r] for r in R))
        model.addConstr(z[c1, c2, s] >= gp.quicksum(x[c1, s, r] for r in R) +
                        gp.quicksum(x[c2, s, r] for r in R) - 1)
    
    
    # Skorður!!
    
    # Lágmarka fjölda í stokki 0 þ.e.a.s. utan stundatöflu
    model.setObjectiveN(
        gp.quicksum(x[n, 0, r] * T[n] for n in N for r in R),
        index = 0,
        priority=4  
    )
    
    if nytni:
        # Hámarka nýtni stofa
        model.setObjectiveN(
            gp.quicksum(Rooms[r]-Students[n] for n in N for r in R for s in S),
            index = 4,
            priority=0
        )
        
    if eins:
        # Hámarka að hafa eins og í fyrra
        model.setObjectiveN(
            -2 * gp.quicksum(x[n,s,r] for n in N for s in course_slots[n] for r in filtered_course_rooms[n])
            -1 * gp.quicksum(x[n,s,r] for n in N for s in course_slots[n] for r in R)
            -1 * gp.quicksum(x[n,s,r] for n in N for s in S for r in filtered_course_rooms[n]),
            index = 2,
            priority=3
        )

    model.setParam('TimeLimit', 60*3)

    model.optimize()
    return model, x

# %%
model, x = ordering(arekstrar=True, eins=True)
# Out:
# Set parameter TimeLimit to value 180
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[x86] - Darwin 23.6.0 23H420)
#
# CPU model: Intel(R) Core(TM) i5-8210Y CPU @ 1.60GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Non-default parameters:
# TimeLimit  180
#
# Academic license 2638823 - for non-commercial use only - registered to jr___@hi.is
# Optimize a model with 73601 rows, 74000 columns and 1030605 nonzeros
# Model fingerprint: 0x9ad4a89b
# Variable types: 0 continuous, 74000 integer (74000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [1e+00, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+02]
#
# ---------------------------------------------------------------------------
# Multi-objectives: starting optimization with 3 objectives...
# ---------------------------------------------------------------------------
#
# Multi-objectives: applying initial presolve...
# ...

# %%
# prenta út niðurstöður
for n in [
      "5054RAF401G20250",
      "5054RAF402G20250",
      "5054RAF403G20250",
      "5054RAF404G20250",
      "5054RAF405G20250",
      "5054RAF406G20250",
      "5054RAF407G20250"
    ]:# námsbraut sem éh er að skoða
    for s in S:
        for r in R:
            if x[n,s,r].X>0.5:
                print(f'{n} er í stokki {s} og stofu {r}')
                print(T[n])
# Out:
# 5054RAF401G20250 er í stokki 6 og stofu VHV-023 Auðarsalur
# 5
# 5054RAF402G20250 er í stokki 4 og stofu V02-158
# 5
# 5054RAF403G20250 er í stokki 2 og stofu V02-157
# 5
# 5054RAF404G20250 er í stokki 7 og stofu N-129
# 4
# 5054RAF405G20250 er í stokki 3 og stofu V02-155
# 4
# 5054RAF406G20250 er í stokki 5 og stofu HT-103
# 4
# 5054RAF407G20250 er í stokki 1 og stofu Ág-301
# 2

# %%
for r in R:
    print(f"stofa {r} með {Rooms[r]} sæti")
    for n in N:
        for s in S:
            if x[n,s,r].X>0.5:
                print(f"Námskeið {n} í slotti {s} með {T[n]} kennslustundir og {Students[n]} nemendur")
# Out:
# stofa VHV-104 með 20.0 sæti
# Námskeið 5053FER614G20250 í slotti 1 með 2 kennslustundir og 12 nemendur
# Námskeið 5053FER409G20250 í slotti 1 með 2 kennslustundir og 6 nemendur
# Námskeið 5051IÐN222F20250 í slotti 6 með 5 kennslustundir og 7 nemendur
# stofa HB-5 með 27.0 sæti
# Námskeið 5056UMV205M20250 í slotti 1 með 5 kennslustundir og 27 nemendur
# Námskeið 5054RAF620M20250 í slotti 6 með 4 kennslustundir og 21 nemendur
# stofa N-128 með 24.0 sæti
# Námskeið 5051VÉL206M20250 í slotti 2 með 5 kennslustundir og 20 nemendur
# Námskeið 5056UMV201G20250 í slotti 5 með 5 kennslustundir og 16 nemendur
# Námskeið 5053LAN219G20250 í slotti 7 með 5 kennslustundir og 11 nemendur
# Námskeið 5053UAU206M20250 í slotti 1 með 4 kennslustundir og 6 nemendur
# Námskeið 5054RAF602M20250 í slotti 3 með 5 kennslustundir og 12 nemendur
# stofa N-121 með 22.0 sæti
# Námskeið 5055LEF616M20250 í slotti 4 með 5 kennslustundir og 10 nemendur
# ...

# %% [markdown]
# ### **Forrit sem prentar núverandi stundatöflu**

# %%
# ['5054RAF201G20250','5055STÆ205G20250','5051TÖL203G20250','5054TÖV201G20250','5055EÐL201G20250','5054RAF050G20250']:
import pandas as pd
from datetime import datetime, timedelta

# Optional: ensure times are datetime
df_schedule["start_time"] = pd.to_datetime(df_schedule["start_time"])
df_schedule["end_time"] = pd.to_datetime(df_schedule["end_time"])

# Select relevant courses
lcids = [
      "5054RAF401G20250",
      "5054RAF402G20250",
      "5054RAF403G20250",
      "5054RAF404G20250",
      "5054RAF405G20250",
      "5054RAF406G20250",
      "5054RAF407G20250"
    ]

df = df_schedule[df_schedule["course_key"].isin(lcids)]

# Define time blocks manually (start, end)
time_blocks = [
    ("08:20", "09:50"),
    ("10:00", "11:30"),
    ("11:40", "13:10"),
    ("13:20", "14:50"),
    ("15:00", "16:30"),
]

days = ['mon', 'tue', 'wed', 'thu', 'fri']

# Initialize timetable dictionary
timetable = {
    f"{start}-{end}": {day: "" for day in days}
    for (start, end) in time_blocks
}

# Fill timetable
for _, row in df.iterrows():
    day = row["day"]
    start = row["start_time"].strftime("%H:%M")
    end = row["end_time"].strftime("%H:%M")
    course = row["course"]

    for block_start, block_end in time_blocks:
        # If the course start falls inside this block
        if start == block_start and day in days:
            key = f"{block_start}-{block_end}"
            # Add course (and optionally room)
            entry = f"{course} ({row['room']})"
            if timetable[key][day]:
                timetable[key][day] += "<br>" + entry
            else:
                timetable[key][day] = entry

# Print Markdown table
print("| Time       | " + " | ".join(day.capitalize() for day in days) + " |")
print("|------------|" + "|".join(["------------"] * len(days)) + "|")

for block in timetable:
    row = [block]
    for day in days:
        row.append(timetable[block][day])
    print("| " + " | ".join(row) + " |")
# Out:
# | Time       | Mon | Tue | Wed | Thu | Fri |
# |------------|------------|------------|------------|------------|------------|
# | 08:20-09:50 |  | Líkindaaðferðir (V02-138) | Greining og uppbygging rása (V02-155) |  | Rafeindatækni 1 (V02-258) |
# | 10:00-11:30 | Rafeindatækni 1 (V02-148, sérstofa VR-2) |  | Rafeindatækni 1 - verklegt (V03-113) | Líkindaaðferðir (V02-156 Sérstofa VR-2) | Greining og uppbygging rása (V02-261) |
# | 11:40-13:10 |  |  |  |  |  |
# | 13:20-14:50 | Rafsegulfræði (V02-156 Sérstofa VR-2) | Greining og uppbygging rása - verklegt (V03-113) | Rafsegulfræði (V02-258) | Greining og uppbygging rása - verklegt (V03-113) | Líkindaaðferðir - verklegt (V03-113) |
# | 15:00-16:30 |  |  |  |  |  |

# %% [markdown]
# ### **Forrit sem prentar út námstöflu gerða af okkur**

# %%
# List of selected courses to show in the timetable
lcids = [
      "5054RAF401G20250",
      "5054RAF402G20250",
      "5054RAF403G20250",
      "5054RAF404G20250",
      "5054RAF405G20250",
      "5054RAF406G20250",
      "5054RAF407G20250"
    ]

# Define the 7 standard slots
standard_slots = {
    1: [("mon", "08:20", "09:50"), ("wed", "10:00", "12:20")],
    2: [("tue", "08:20", "09:50"), ("thu", "10:00", "12:20")],
    3: [("wed", "08:20", "09:50"), ("fri", "10:00", "12:20")],
    4: [("thu", "08:20", "09:50"), ("mon", "10:00", "12:20")],
    5: [("fri", "08:20", "09:50"), ("tue", "10:00", "12:20")],
    6: [("mon", "13:20", "15:40"), ("wed", "13:20", "14:50")],
    7: [("tue", "13:20", "15:40"), ("thu", "13:20", "14:50")]
}

# Days and known time blocks
days = ['mon', 'tue', 'wed', 'thu', 'fri']
time_blocks = [
    ("08:20", "09:50"),
    ("10:00", "12:20"),
    ("13:20", "14:50"),
    ("13:20", "15:40")
]
time_available = {'08:20-09:50':2, '10:00-12:20': 3, '13:20-14:50': 2, '13:20-15:40': 3}

# Step 1: Extract selected solution from Gurobi
selected = []
for n in lcids:
  for s in S:
    for r in R:
      if (n,s,r) in NSR:
        if x[n,s,r].X > 0.5 and n in lcids and s != 0:
          selected.append((n, s, r))
print(selected)
# Step 2: Build course name mapping
course_names = df_schedule.set_index("course_key")["course"].to_dict()

# Step 3: Initialize timetable
timetable = {
    f"{start}-{end}": {day: "" for day in days}
    for (start, end) in time_blocks
}

# Step 4: Fill the timetable
for n, s, r in selected:
    course_name = course_names.get(n, n)
    timar = T[n]
    for (day, start, end) in standard_slots.get(s, []):
      if timar > 0:
        time_key = f"{start}-{end}"
        if time_key not in timetable:
            timetable[time_key] = {day: ""}
        entry = f"{course_name} ({r})"
        print(entry," is in slot ", s)
        if timetable[time_key][day]:
            timetable[time_key][day] += "<br>" + entry
        else:
            timetable[time_key][day] = entry
        timar = timar - time_available[time_key]

# Step 5: Print Markdown timetable
print("| Time       | " + " | ".join(day.capitalize() for day in days) + " |")
print("|------------|" + "|".join(["------------"] * len(days)) + "|")

for time in sorted(timetable.keys()):
    row = [time]
    for day in days:
        row.append(timetable[time].get(day, ""))
    print("| " + " | ".join(row) + " |")
# Out:
# [('5054RAF401G20250', 3, 'N-131'), ('5054RAF402G20250', 6, 'Ág-311'), ('5054RAF403G20250', 4, 'HB-2'), ('5054RAF404G20250', 2, 'N-131'), ('5054RAF405G20250', 7, 'V02-138'), ('5054RAF406G20250', 1, 'HB-4'), ('5054RAF407G20250', 5, 'N-131')]
# Greining og uppbygging rása (N-131)  is in slot  3
# Greining og uppbygging rása (N-131)  is in slot  3
# Rafsegulfræði (Ág-311)  is in slot  6
# Rafsegulfræði (Ág-311)  is in slot  6
# Rafeindatækni 1 (HB-2)  is in slot  4
# Rafeindatækni 1 (HB-2)  is in slot  4
# Líkindaaðferðir (N-131)  is in slot  2
# Líkindaaðferðir (N-131)  is in slot  2
# Greining og uppbygging rása - verklegt (V02-138)  is in slot  7
# Greining og uppbygging rása - verklegt (V02-138)  is in slot  7
# Rafeindatækni 1 - verklegt (HB-4)  is in slot  1
# Rafeindatækni 1 - verklegt (HB-4)  is in slot  1
# Líkindaaðferðir - verklegt (N-131)  is in slot  5
# | Time       | Mon | Tue | Wed | Thu | Fri |
# ...

# %% [markdown]
# | Time       | Mon | Tue | Wed | Thu | Fri |
# |------------|------------|------------|------------|------------|------------|
# | 08:20-09:50 | Líkindaaðferðir - verklegt (Ág-301) | Rafeindatækni 1 (V02-157) | Greining og uppbygging rása - verklegt (V02-155) | Rafsegulfræði (V02-158) | Rafeindatækni 1 - verklegt (HT-103) |
# | 10:00-12:20 | Rafsegulfræði (V02-158) | Rafeindatækni 1 - verklegt (HT-103) |  | Rafeindatækni 1 (V02-157) | Greining og uppbygging rása - verklegt (V02-155) |
# | 13:20-14:50 |  |  | Greining og uppbygging rása (VHV-023 Auðarsalur) | Líkindaaðferðir (N-129) |  |
# | 13:20-15:40 | Greining og uppbygging rása (VHV-023 Auðarsalur) | Líkindaaðferðir (N-129) |  |  |  |

# %% [markdown]
# ### **Forrit sem reiknar fjölda árekstra**

# %%
# Now count the number of clashes in Gurobi Solution:
total_number_in_clash = 0
for (n1,n2) in Clash.keys():
  for s in S:
    z1 = sum([x[n1,s,r].X for r in R if (n1,s,r) in NSR])
    z2 = sum([x[n2,s,r].X for r in R if (n2,s,r) in NSR])
    if z1 > 0.1 and z2 > 0.5:
      total_number_in_clash += Clash[n1,n2]
total_number_in_clash
# Out:
# 539

# %% [markdown]
# ### Finnur hversu svipað það var í fyrra
